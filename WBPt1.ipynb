# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

file_path =r'C:\Users\Raima Das\Downloads\WorldBankPopulation\WorldBankPopulation.csv'
df= pd.read_csv(file_path, skiprows=4)
plt.figure(figsize=(20,12))
plt.bar(df['Country Name'],df['2023'])
plt.xlabel('Country Name')
plt.ylabel('Population in 2023')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()
